# %%
import numpy as np
from numpy import genfromtxt
from os import listdir
import time 
import pandas
import random
import sklearn
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


#Loading the file names
df = pandas.read_csv('project/0.xyz', delimiter=',')
print (df)
# Out:
#                                                    112
# 0    Lattice="13.2610233822 0.0 0.0 6.63051168107 1...
# 1    S      9.84149906       5.68205035       9.017...
# 2    S      4.97291082       2.87123135       8.935...
# 3    S      4.97291143       4.66756213       6.394...
# 4    S      6.52871345       1.97281120       6.395...
# 5    S      8.28811195       2.98869329       9.018...
# 6    S      6.73230993       5.68344422       9.018...
# 7    S      3.41952432       1.97420508       6.396...
# 8    S      8.28811256       4.78502407       6.478...
# 9    Co      4.97288377       0.95703193       7.70...
# 10   Co      3.31525584       3.82812771       7.70...
# 11   Co      4.97288377       2.87109578       5.00...
# 12   Co      6.63051169       3.82812771       7.70...
# 13   Co      1.65471944       0.95535525       5.67...
# 14   Co      1.66053641       0.95870860       9.73...
# 15   S      3.21098737       1.85392263      14.431...
# ...
